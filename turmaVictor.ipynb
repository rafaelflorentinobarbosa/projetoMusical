# %%
# Importar o pandas

import pandas as pd

# %%
df = pd.read_csv('datasets/turmavictor.csv')

# %%
df.head()
# Out:
#    rock  rap  mpb  reggae  funk  sertanejo  gospel  eletronica professor  \
# 0     2    4    3       1     4          4       4           2    Victor
# 1     2    5    2       2     3          5       5           5    Victor
# 2     4    3    3       3     2          4       3           4    Victor
# 3     1    1    4       3     3          3       3           1    Victor
# 4     4    4    1       2     2          1       1           4    Victor
#
#    faixa_etaria
# 0       18 - 25
# 1       18 - 25
# 2       18 - 25
# 3       25 - 39
# 4       25 - 39

# %%
pequisa_musical = df.drop(columns=['professor',' faixa_etaria'])

pequisa_musical.head()
# Out:
#    rock  rap  mpb  reggae  funk  sertanejo  gospel  eletronica
# 0     2    4    3       1     4          4       4           2
# 1     2    5    2       2     3          5       5           5
# 2     4    3    3       3     2          4       3           4
# 3     1    1    4       3     3          3       3           1
# 4     4    4    1       2     2          1       1           4

# %%
import matplotlib.pyplot as plt

# Calcular a soma dos votos para cada gênero
soma_votos = pequisa_musical.sum()

# Criar o gráfico de barras horizontais
plt.figure(figsize=(10, 6))
soma_votos.plot(kind='barh', color='skyblue')

# Adicionar título e rótulos
plt.title('Soma dos Votos por Gênero Musical - Turma do Professor Victor')
plt.xlabel('Soma dos Votos')
plt.ylabel('Gênero Musical')

# Exibir o gráfico
plt.tight_layout()
plt.show()
plt.show()

# %%
# versão colorida

import pandas as pd
import matplotlib.pyplot as plt


df = pd.read_csv('datasets/turmavictor.csv')


cores = ['black','orange', 'blue', 'green', 'red', 'purple', 'cyan', 'olive']  


plt.figure(figsize=(10, 6))
soma_votos.plot(kind='barh', color=cores)


plt.title('Soma dos Votos por Gênero Musical')
plt.xlabel('Soma dos Votos')
plt.ylabel('Gênero Musical')


plt.tight_layout()
plt.show()

# %% [markdown]
# # link musica
# # https://sunoai.ai/music/40246cb910664ba9a2238989fa64f153
